# %%
from __future__ import print_function, division
# %matplotlib inline
import matplotlib.pylab as plt
import os, sys
import numpy as np
import pandas as pd
import os, shutil, glob
import urllib
import wget
import subprocess
import logging
from ete3 import NCBITaxa
ncbi = NCBITaxa()
from collections import OrderedDict, Counter
import time

logging.basicConfig(level=logging.DEBUG,
                    format='%(asctime)s [%(name)s] %(levelname)s : %(message)s')
logger = logging.getLogger(__name__)

#sys.path.append('/misc/workspace/amromics/amromics/')
#from  amromics.utils.bioseq import read_sequence_file

# %%
ncbi_root = '/misc/workspace/data/ncbi'
ncbi_url = 'ftp://ftp.ncbi.nlm.nih.gov/'

# %%
def download_assembly(genome_id):
    """
    Download the the genome file from patric if not there already
    """
    #make sure directory exist
    directory = os.path.join(patric_root,'genomes',genome_id)
    if not os.path.exists(directory):
        os.makedirs(directory)
    genome_file = os.path.join(directory, genome_id + '.fna')
    if os.path.isfile(genome_file):
        logger.info('Genome {} has been downloaded'.format(genome_id))
        return genome_file
    genome_url = patric_url + 'genomes/' + genome_id + '/' + genome_id + '.fna'    
    logger.info('Downloaded {}'.format(genome_id))
    return wget.download(genome_url, genome_file)


def run_command(cmd, timing_log=None):
    """
    Run a command line, return the returning code of the command
    :param cmd:
    :param timing_log:
    :return:
    """
    if timing_log is not None:
        cmd = '/usr/bin/time --append -v -o {} bash -c "{}"'.format(timing_log, cmd)
    #logger.info('Running "{}'.format(cmd))
    ret = os.system(cmd)
    if ret != 0:
        logger.error('Running "{}" returns {}'.format(cmd, ret))
    return ret


def get_linages(taxon_id, linage_ranks = ['superkingdom', 'phylum', 'class', 'order', 'family', 'genus', 'species']):
    lin_ids = ncbi.get_lineage(taxon_id)
    lin_names =  ncbi.get_taxid_translator(lin_ids)
    lin_ranks = ncbi.get_rank(lin_ids)
    #swap key<-> value
    lin_ranks = {lin_ranks[key]: key for key in lin_ranks}
    
    ret_names = [None] * len(linage_ranks)
    ret_ids = [None] * len(linage_ranks)
    for ii, rank in enumerate(linage_ranks):
        if rank in lin_ranks:
            lin_id = lin_ranks[rank]
            ret_ids[ii] = lin_id
            ret_names[ii] = lin_names[lin_id]
    return ret_ids, ret_names            
    

def download_patric_assembly_curl(genome_id):
    """
    Download the the genome file from patric if not there already
    """
    #make sure directory exist
    directory = os.path.join(patric_root,'genomes',genome_id)
    if not os.path.exists(directory):
        os.makedirs(directory)
    genome_file = os.path.join(directory, genome_id + '.fna')
    genome_file_gz = os.path.join(directory, genome_id + '.fna.gz')
    if os.path.isfile(genome_file_gz):
        logger.info('Previously done {}'.format(genome_id))
        return genome_file_gz
    elif os.path.isfile(genome_file):
        logger.info('Partly done {}'.format(genome_id))
        cmd = 'gzip ' + genome_file
        if run_command(cmd) != 0:
            return None
        else:
            assert os.path.isfile(genome_file_gz)
            return genome_file_gz
    else:
        # logger.info('Download')
        genome_url = patric_url + 'genomes/' + genome_id + '/' + genome_id + '.fna'    
        time.sleep(3)
        cmd = 'curl -R -o {} {}'.format(genome_file, genome_url)
        if run_command(cmd) != 0:
            return None
        cmd = 'gzip ' + genome_file
        if run_command(cmd) != 0:
            return None
        else:
            assert os.path.isfile(genome_file_gz)
            return genome_file_gz

def download_refseq_assembly_curl(refseq_dir):
    """
    Download the the genome file from refseq if not there already
    """
    #make sure directory exist
    path = refseq_dir[len(ncbi_url):]
    genome_path = os.path.join(ncbi_root, path)
    os.makedirs(genome_path, exist_ok=True)
    genome_id = refseq_dir.split('/')[-1]
    
    genome_file = os.path.join(genome_path, genome_id + '_genomic.fna.gz')
    annotation_file = os.path.join(genome_path, genome_id + '_genomic.gbff.gz')
    
    genome_url = refseq_dir + '/' + genome_id + '_genomic.fna.gz'
    gbf_url = refseq_dir + '/' + genome_id + '_genomic.gbff.gz'
    if not os.path.isfile(genome_file):
        cmd = 'curl --retry 10 -R -o {} {}'.format(genome_file, genome_url)
        time.sleep(1)
        ret = run_command(cmd)
        if ret != 0:
            logger.error('Error downloading {} return {}'.format(genome_url, ret))
            genome_file = None
        else:
            logger.info('Downloaded {}'.format(genome_file))
    else:
        pass
        #logger.info('File {} exists!'.format(genome_file))
    
    if not os.path.isfile(annotation_file):
        cmd = 'curl --retry 3 -R -o {} {}'.format(annotation_file, gbf_url)
        time.sleep(1)
        ret = run_command(cmd)
        if ret != 0:
            logger.error('Error downloading {} return {}'.format(gbf_url, ret))
            annotation_file = None 
        else:
            logger.info('Downloaded {}'.format(annotation_file))
    else:
        #logger.info('File {} exists!'.format(annotation_file))
        pass
    return genome_file, annotation_file

# %% [markdown]
# # Data preprocessing
#
# ## Get lineage information
#
# As the lineage information from patric might have been outdated, we refer to NCBI to update the lineage information. As in turns out, there are changes to NCBI taxatomy incuding taxon IDs and taxon name. In fact, we
# infor lieage information directly from taxon ID.

# %%
# #gl_df = pd.read_table(os.path.join(patric_root, 'RELEASE_NOTES', 'genome_lineage'),  dtype={'genome_id': str})


# gm_df = pd.read_table(os.path.join(patric_root, 'RELEASE_NOTES', 'genome_metadata'), dtype={'genome_id': str})
# #note that i decided to get the linage information instead of taking from gl
# linages = gm_df['taxon_id'].apply(lambda x:get_linages(x))
# linage_ids, linage_names  = zip(*linages)
# superkingdom_names, phylum_names, class_names, order_names, family_names, genus_names, species_names = zip(*linage_names)
# superkingdom_ids, phylum_ids, class_ids, order_ids, family_ids, genus_ids, species_ids = zip(*linage_ids)

# gm_df['species_name'] = species_names
# gm_df['genus_name'] = genus_names
# gm_df['species_id'] = species_ids
# gm_df['genus_id'] = genus_ids

# #gm_df['family'] = family_names
# #gm_df['order'] = order_names
# #gm_df['phylum'] = phylum_names
# #gm_df['domain'] = superkingdom_names

# #(gm_df['domain'] == 'Bacteria')
# #gm_df = gm_df[(gm_df['genome_status'] != 'Plasmid') & (gm_df['contigs'] < 500) ]
# print(len(gm_df))

# %% [markdown]
# We grouped the data in species, and pick those relavant species. Note that many Salmonella taxa do not have a
# species name, and hence we get those from genus

# %%
#Look at the list of most common specices, and found:
# Counter(gm_df['species']).most_common()
amr_species = [    
    # 'Mycobacterium tuberculosis', # 27993),
    'Escherichia coli', # 23309),
    'Streptococcus pneumoniae', # 20697),
    'Salmonella enterica', # 18169),
    'Staphylococcus aureus', # 12878),
    'Klebsiella pneumoniae', # 12246),
    'Acinetobacter baumannii', # 6936),
    # None, # 5303),
    'Pseudomonas aeruginosa', # 5263),
    'Neisseria gonorrhoeae', # 5096),
    # 'Listeria monocytogenes', # 4111),
    # 'Campylobacter jejuni', # 2973),
    # 'uncultured Pelagibacteraceae bacterium', # 2390),
    # 'Clostridioides difficile', # 2345),
     'Enterococcus faecium', # 2189),
    # 'Streptococcus pyogenes', # 2063),
    # 'Neisseria meningitidis', # 2001),
    # 'Mycobacteroides abscessus', # 1734),
    # 'Campylobacter coli', # 1724),
    # 'Helicobacter pylori', # 1644),
    # 'Burkholderia pseudomallei', # 1615),
    'Enterococcus faecalis', # 1564),
    # 'Pseudomonas viridiflava', # 1540),
    'Shigella sonnei', # 1532),
    # 'Vibrio parahaemolyticus', # 1474),
    # 'Streptococcus agalactiae', # 1355),
    'Vibrio cholerae', # 1350),
    'Streptococcus suis', # 1319),
    # 'Bacillus cereus', # 1252),
    'Enterobacter cloacae', # 1187)
    'Corynebacterium diphtheriae',
]
#gm_df = gm_df[(gm_df['genus_name'] == 'Salmonella') | (gm_df['species_name'].isin(amr_species))]


amr_species = [    
    # 'Mycobacterium tuberculosis', # 27993),
   'Escherichia coli', # 23309),
#=#    'Streptococcus pneumoniae', # 20697),
#=#     'Salmonella enterica', # 18169),
    'Staphylococcus aureus', # 12878),
    'Klebsiella pneumoniae', # 12246),
#=#     'Acinetobacter baumannii', # 6936),
    # None, # 5303),
#=#     'Pseudomonas aeruginosa', # 5263),
#=#     'Neisseria gonorrhoeae', # 5096),
    # 'Listeria monocytogenes', # 4111),
    # 'Campylobacter jejuni', # 2973),
    # 'uncultured Pelagibacteraceae bacterium', # 2390),
    # 'Clostridioides difficile', # 2345),
    # 'Enterococcus faecium', # 2189),
    # 'Streptococcus pyogenes', # 2063),
    # 'Neisseria meningitidis', # 2001),
    # 'Mycobacteroides abscessus', # 1734),
    # 'Campylobacter coli', # 1724),
    # 'Helicobacter pylori', # 1644),
    # 'Burkholderia pseudomallei', # 1615),
#=#     'Enterococcus faecalis', # 1564),
    # 'Pseudomonas viridiflava', # 1540),
#=#     'Shigella sonnei', # 1532),
    # 'Vibrio parahaemolyticus', # 1474),
    # 'Streptococcus agalactiae', # 1355),
    # 'Vibrio cholerae', # 1350),
#=#     'Streptococcus suis', # 1319),
    # 'Bacillus cereus', # 1252),
    # 'Enterobacter cloacae', # 1187)
###    'Corynebacterium diphtheriae',
]

# %%
refseq_assemly = os.path.join(ncbi_root, 'assembly_summary_refseq.txt')


refseq_df = pd.read_csv(refseq_assemly, sep='\t', header=1)
refseq_df.rename({'# assembly_accession':'assembly_accession'},axis=1, inplace=True)

all_species_ids = set(refseq_df['species_taxid'])
species_map = {}
for taxon_id in all_species_ids:
    try:
        r = get_linages(taxon_id)
        species = r[1][6]
        genus = r[1][5]
        domain = r[1][0]        
        species_map[taxon_id] = (species, genus, domain)
    except:
        species_map[taxon_id] = (None, None, None)  
        

refseq_df['species_name'] = refseq_df['species_taxid'].apply(lambda x:species_map[x][0])
refseq_df['genus_name']   = refseq_df['species_taxid'].apply(lambda x:species_map[x][1])
refseq_df['domain_name']  = refseq_df['species_taxid'].apply(lambda x:species_map[x][2])

#refseq_df = refseq_df[(refseq_df['genus_name'] == 'Salmonella') | (refseq_df['species_name'].isin(amr_species))].reset_index()
df = refseq_df[(refseq_df['species_name'].isin(amr_species))].reset_index()

Counter(df['species_name'])
# Out:
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3552: DtypeWarning: Columns (20) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2884447 was translated into 2792859
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 1900 was translated into 1961
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2501474 was translated into 2500546
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2758574 was translated into 2758440
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2758577 was translated into 2758573
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2841033 was translated into 2841032
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2759659 was translated into 2760083
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2891943 was translated into 2815579
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2498857 was translated into 2498858
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2498859 was translated into 2498858
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2893020 was translated into 2755382
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2503034 was translated into 2505976
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2816245 was translated into 2816244
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2816246 was translated into 2816244
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2816247 was translated into 2816244
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2898420 was translated into 2713171
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2899824 was translated into 2899822
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2899825 was translated into 2899822
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2769496 was translated into 2842200
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2902425 was translated into 2901869
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2817474 was translated into 2817475
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2904527 was translated into 82989
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2905875 was translated into 2905874
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2905876 was translated into 2905874
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2905878 was translated into 2905877
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2906071 was translated into 2765360
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2775032 was translated into 2746961
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2775033 was translated into 2746961
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2715211 was translated into 2758038
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 425933 was translated into 79879
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2768163 was translated into 2768161
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2768164 was translated into 2768162
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 166934 was translated into 77608
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 1217700 was translated into 70347
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2792482 was translated into 2792481
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2847993 was translated into 2847991
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 307251 was translated into 298
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2902426 was translated into 2901869
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2545414 was translated into 2562451
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2810353 was translated into 2810351
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 189515 was translated into 134386
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2812557 was translated into 2812555
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2812630 was translated into 2758573
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2812897 was translated into 2726117
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2682802 was translated into 2654874
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 716759 was translated into 2944916
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2814245 was translated into 2814244
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2816858 was translated into 2816859
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2687303 was translated into 1255
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2820662 was translated into 2834768
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 68178 was translated into 1894
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 68210 was translated into 47760
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2692266 was translated into 2692265
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2696286 was translated into 2696285
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2828362 was translated into 2828363
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2828364 was translated into 2828363
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2854762 was translated into 2854755
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2854763 was translated into 2854755
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2854764 was translated into 2854755
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 67349 was translated into 1894
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2831676 was translated into 2831523
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2803866 was translated into 2828363
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2834769 was translated into 2834768
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2834770 was translated into 2834768
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2704091 was translated into 2559928
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2704092 was translated into 2559928
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2049333 was translated into 2917965
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 215842 was translated into 2883100
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 1264596 was translated into 2878388
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2575373 was translated into 2575440
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 1789652 was translated into 2746961
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 741091 was translated into 2703885
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 482825 was translated into 172827
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2583375 was translated into 77608
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2584181 was translated into 2486008
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2585212 was translated into 2585211
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2847990 was translated into 2847989
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2848007 was translated into 754515
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2848008 was translated into 754515
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2586910 was translated into 1857024
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2853241 was translated into 2799571
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2854754 was translated into 2854755
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2854756 was translated into 2854755
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2854757 was translated into 2854755
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2854758 was translated into 2854755
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2854759 was translated into 2854755
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2854760 was translated into 2854755
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2854761 was translated into 2854755
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2593677 was translated into 2595054
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2725561 was translated into 2725562
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 1546149 was translated into 164759
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 366526 was translated into 2746961
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2596922 was translated into 2703794
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2596923 was translated into 129985
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2597824 was translated into 2597660
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 501011 was translated into 501010
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2734910 was translated into 2734909
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2734911 was translated into 2734909
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2604327 was translated into 2919747
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2735525 was translated into 2735528
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2867235 was translated into 2867236
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2867517 was translated into 2867516
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2867519 was translated into 2867518
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2867960 was translated into 2867412
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2738412 was translated into 2735723
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2738411 was translated into 2735723
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 1955273 was translated into 2912308
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2742999 was translated into 2831468
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2875765 was translated into 2875764
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2875766 was translated into 2875764
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2875767 was translated into 2875764
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2875768 was translated into 2875764
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2875769 was translated into 2875764
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2875770 was translated into 2875764
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 516701 was translated into 141693
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2746960 was translated into 2746961
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2746958 was translated into 2746961
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2746962 was translated into 2746961
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2746959 was translated into 2746961
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 1962644 was translated into 1945581
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2881053 was translated into 2881052
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2881054 was translated into 2881055
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2883171 was translated into 2883169
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2883172 was translated into 2883169
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2883173 was translated into 2883169
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2883174 was translated into 2883169
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# /misc/usr/sw/conda/Miniconda3-py39_4.12.0/envs/amromics_dev/lib/python3.7/site-packages/ete3/ncbi_taxonomy/ncbiquery.py:243: UserWarning: taxid 2883170 was translated into 2883169
#   warnings.warn("taxid %s was translated into %s" %(taxid, merged_conversion[taxid]))
# Counter({'Escherichia coli': 26392,
#          'Staphylococcus aureus': 13556,
#          'Klebsiella pneumoniae': 12123})

# %%
complete_df = df[df.assembly_level == 'Complete Genome']
not_complete_df = df[df.assembly_level != 'Complete Genome']
#[['assembly_accession', 'biosample', 'infraspecific_name','seq_rel_date', 'asm_name', 'ftp_path']]#.to_csv(None, index=False)
not_complete_df = not_complete_df[not_complete_df['biosample'].isin(complete_df['biosample'])]

not_complete_df
# Out:
#         index assembly_accession   bioproject     biosample  \
# 121      1996    GCF_000166595.1  PRJNA224116  SAMN02436016
# 2156    14702    GCF_000513035.1  PRJNA224116  SAMN02304041
# 3989    17239    GCF_000567725.1  PRJNA224116  SAMN02138579
# 6651    24704    GCF_000735285.1  PRJNA224116  SAMN02768808
# 6744    25961    GCF_000770035.1  PRJNA224116  SAMN02951658
# 9738    54076    GCF_001462715.1  PRJNA224116  SAMN04158281
# 9739    54077    GCF_001462735.1  PRJNA224116  SAMN04158282
# 9748    54086    GCF_001462925.1  PRJNA224116  SAMN04158294
# 10949   64627    GCF_001728785.1  PRJNA224116  SAMN04191551
# 19094  101926    GCF_003008295.1  PRJNA224116  SAMN08637771
# 23555  123283    GCF_003980305.1  PRJNA224116  SAMN08161240
# 36722  186107    GCF_016785485.1  PRJNA224116  SAMN16387362
# 36723  186108    GCF_016785505.1  PRJNA224116  SAMN16387357
# 36724  186109    GCF_016785525.1  PRJNA224116  SAMN16387510
# 36725  186110    GCF_016785585.1  PRJNA224116  SAMN16387507
# 36727  186112    GCF_016785625.1  PRJNA224116  SAMN16387502
# 36731  186116    GCF_016785705.1  PRJNA224116  SAMN16387483
# 36736  186130    GCF_016786025.1  PRJNA224116  SAMN16387358
# 36737  186131    GCF_016786035.1  PRJNA224116  SAMN16387495
# 36739  186133    GCF_016786075.1  PRJNA224116  SAMN16387482
# 36740  186134    GCF_016786085.1  PRJNA224116  SAMN16387487
# 36741  186135    GCF_016786125.1  PRJNA224116  SAMN16387489
# 36742  186136    GCF_016786145.1  PRJNA224116  SAMN16387494
# 36743  186137    GCF_016786155.1  PRJNA224116  SAMN16387490
# 36752  186167    GCF_016791825.1  PRJNA224116  SAMN16387501
# 36763  186178    GCF_016792035.1  PRJNA224116  SAMN16387496
# 43012  213950    GCF_021136355.1  PRJNA224116  SAMN21016516
# 43021  213959    GCF_021136665.1  PRJNA224116  SAMN21016508
# 43022  213960    GCF_021136695.1  PRJNA224116  SAMN21016509
# 43024  213962    GCF_021136735.1  PRJNA224116  SAMN21016532
# 43026  213964    GCF_021136775.1  PRJNA224116  SAMN21016533
# 43028  213966    GCF_021136815.1  PRJNA224116  SAMN21016531
# 43029  213967    GCF_021136835.1  PRJNA224116  SAMN21016528
# 43030  213968    GCF_021136845.1  PRJNA224116  SAMN21016529
# 43031  213969    GCF_021136875.1  PRJNA224116  SAMN21016527
# 43032  213970    GCF_021136895.1  PRJNA224116  SAMN21016534
# 43035  213973    GCF_021136945.1  PRJNA224116  SAMN21016525
# 43036  213974    GCF_021136955.1  PRJNA224116  SAMN21016524
# 43039  213977    GCF_021137035.1  PRJNA224116  SAMN21016539
# 43044  213982    GCF_021137135.1  PRJNA224116  SAMN21016540
# 43046  213984    GCF_021137155.1  PRJNA224116  SAMN21016517
# 43047  213985    GCF_021137165.1  PRJNA224116  SAMN21016535
# 43048  213986    GCF_021137215.1  PRJNA224116  SAMN21016518
# 43049  213987    GCF_021137235.1  PRJNA224116  SAMN21016544
# 43050  213988    GCF_021137255.1  PRJNA224116  SAMN21016545
# 43051  213989    GCF_021137275.1  PRJNA224116  SAMN21016543
# 43052  213990    GCF_021137295.1  PRJNA224116  SAMN21016542
# 43053  213991    GCF_021137315.1  PRJNA224116  SAMN21016479
#
#               wgs_master refseq_category    taxid  species_taxid  \
# 121       AELD00000000.1              na   913088            562
# 2156      AVCD00000000.1              na  1343836            562
# 3989      JCNV00000000.1              na  1328373            573
# 6651      JPIQ00000000.1              na      573            573
# 6744      JPUT00000000.1              na      562            562
# 9738      LNGY00000000.1              na      562            562
# 9739      LNGZ00000000.1              na      573            573
# 9748      LNHL00000000.1              na      562            562
# 10949     LYVB00000000.1              na      562            562
# 19094     PVPK00000000.1              na      562            562
# 23555     PNRR00000000.1              na      562            562
# 36722  JADBEX000000000.1              na      562            562
# 36723  JADBFC000000000.1              na      562            562
# 36724  JADCMM000000000.1              na      562            562
# 36725  JADBFF000000000.1              na      562            562
# 36727  JADBFJ000000000.1              na      562            562
# 36731  JADBFO000000000.1              na      562            562
# 36736  JADBFB000000000.1              na      562            562
# 36737  JADBFV000000000.1              na      562            562
# 36739  JADBFP000000000.1              na      562            562
# 36740  JADCMS000000000.1              na      562            562
# 36741  JADBFY000000000.1              na      562            562
# 36742  JADBFW000000000.1              na      562            562
# 36743  JADCMY000000000.1              na      562            562
# 36752  JADBFK000000000.1              na      562            562
# 36763  JADBFU000000000.1              na      562            562
# 43012  JAIUAO000000000.1              na      573            573
# 43021  JAIUAY000000000.1              na      573            573
# 43022  JAIUAX000000000.1              na      573            573
# 43024  JAIUBD000000000.1              na      573            573
# 43026  JAIUBC000000000.1              na      573            573
# 43028  JAIUBE000000000.1              na      573            573
# 43029  JAIUBH000000000.1              na      573            573
# 43030  JAIUBG000000000.1              na      573            573
# 43031  JAIUBI000000000.1              na      573            573
# 43032  JAIUBJ000000000.1              na      573            573
# 43035  JAIUBL000000000.1              na      573            573
# 43036  JAIUBM000000000.1              na      573            573
# 43039  JAIUBS000000000.1              na      573            573
# 43044  JAIUBZ000000000.1              na      573            573
# 43046  JAIUBY000000000.1              na      573            573
# 43047  JAIUBW000000000.1              na      573            573
# 43048  JAIUBX000000000.1              na      573            573
# 43049  JAIUCB000000000.1              na      573            573
# 43050  JAIUCE000000000.1              na      573            573
# 43051  JAIUCA000000000.1              na      573            573
# 43052  JAIUCC000000000.1              na      573            573
# 43053  JAIUCD000000000.1              na      573            573
#
#                               organism_name    infraspecific_name  ...  \
# 121                Escherichia coli TW11681        strain=TW11681  ...
# 2156   Escherichia coli O157:H7 str. F8092B         strain=F8092B  ...
# 3989           Klebsiella pneumoniae MGH 39         strain=MGH 39  ...
# 6651                  Klebsiella pneumoniae          strain=IA565  ...
# 6744                       Escherichia coli  strain=2011EL-1370-2  ...
# 9738                       Escherichia coli         strain=K71-77  ...
# 9739                  Klebsiella pneumoniae         strain=K66-45  ...
# 9748                       Escherichia coli       strain=50579417  ...
# 10949                      Escherichia coli       strain=FRIK2069  ...
# 19094                      Escherichia coli        strain=BA22372  ...
# 23555                      Escherichia coli        strain=TW10590  ...
# 36722                      Escherichia coli        strain=BS74R-D  ...
# 36723                      Escherichia coli        strain=BS15R-A  ...
# 36724                      Escherichia coli     strain=EM20-18-50  ...
# 36725                      Escherichia coli     strain=EM10-18-28  ...
# 36727                      Escherichia coli     strain=EM06-18-14  ...
# 36731                      Escherichia coli      strain=EF7-18-51  ...
# 36736                      Escherichia coli        strain=BS90R-A  ...
# 36737                      Escherichia coli     strain=EH09-18-41  ...
# 36739                      Escherichia coli      strain=EF5-18-41  ...
# 36740                      Escherichia coli      strain=EF7-18-58  ...
# 36741                      Escherichia coli     strain=EH01-18-02  ...
# 36742                      Escherichia coli     strain=EH08-18-36  ...
# 36743                      Escherichia coli   strain=EH01-18-04-A  ...
# 36752                      Escherichia coli     strain=EM03-18-08  ...
# 36763                      Escherichia coli     strain=EH10-18-47  ...
# 43012                 Klebsiella pneumoniae          strain=BD-41  ...
# 43021                 Klebsiella pneumoniae          strain=BD-13  ...
# 43022                 Klebsiella pneumoniae          strain=BD-14  ...
# 43024                 Klebsiella pneumoniae        strain=7008.20  ...
# 43026                 Klebsiella pneumoniae        strain=7011.62  ...
# 43028                 Klebsiella pneumoniae        strain=6911.28  ...
# 43029                 Klebsiella pneumoniae        strain=6711.43  ...
# 43030                 Klebsiella pneumoniae        strain=6712.08  ...
# 43031                 Klebsiella pneumoniae        strain=6710.71  ...
# 43032                 Klebsiella pneumoniae      strain=6709.15-I  ...
# 43035                 Klebsiella pneumoniae        strain=6611.48  ...
# 43036                 Klebsiella pneumoniae        strain=6604.68  ...
# 43039                 Klebsiella pneumoniae        strain=5208.51  ...
# 43044                 Klebsiella pneumoniae     strain=0213293972  ...
# 43046                 Klebsiella pneumoniae    strain=400195-1-18  ...
# 43047                 Klebsiella pneumoniae        strain=4906.28  ...
# 43048                 Klebsiella pneumoniae    strain=400195-2-18  ...
# 43049                 Klebsiella pneumoniae     strain=1613163991  ...
# 43050                 Klebsiella pneumoniae     strain=0113481141  ...
# 43051                 Klebsiella pneumoniae     strain=1613258639  ...
# 43052                 Klebsiella pneumoniae     strain=1613015451  ...
# 43053                 Klebsiella pneumoniae   strain=1230_0791_KP  ...
#
#                                                submitter  gbrs_paired_asm  \
# 121                        Institute for Genome Sciences  GCA_000166595.2
# 2156                                                USDA  GCA_000513035.1
# 3989                                     Broad Institute  GCA_000567725.1
# 6651                              University of Michigan  GCA_000735285.1
# 6744          Centers for Disease Control and Prevention  GCA_000770035.1
# 9738   Norwegian National Advisory Unit on Detection ...  GCA_001462715.1
# 9739   Norwegian National Advisory Unit on Detection ...  GCA_001462735.1
# 9748   Norwegian National Advisory Unit on Detection ...  GCA_001462925.1
# 10949                    US Food and Drug Administration  GCA_001728785.1
# 19094                          Christian Medical College  GCA_003008295.1
# 23555         University of Maryland, School of Medicine  GCA_003980305.1
# 36722                                 University of Bern  GCA_016785485.1
# 36723                                 University of Bern  GCA_016785505.1
# 36724                                 University of Bern  GCA_016785525.1
# 36725                                 University of Bern  GCA_016785585.1
# 36727                                 University of Bern  GCA_016785625.1
# 36731                                 University of Bern  GCA_016785705.1
# 36736                                 University of Bern  GCA_016786025.1
# 36737                                 University of Bern  GCA_016786035.1
# 36739                                 University of Bern  GCA_016786075.1
# 36740                                 University of Bern  GCA_016786085.1
# 36741                                 University of Bern  GCA_016786125.1
# 36742                                 University of Bern  GCA_016786145.1
# 36743                                 University of Bern  GCA_016786155.1
# 36752                                 University of Bern  GCA_016791825.1
# 36763                                 University of Bern  GCA_016792035.1
# 43012                                 University of Bern  GCA_021136355.1
# 43021                                 University of Bern  GCA_021136665.1
# 43022                                 University of Bern  GCA_021136695.1
# 43024                                 University of Bern  GCA_021136735.1
# 43026                                 University of Bern  GCA_021136775.1
# 43028                                 University of Bern  GCA_021136815.1
# 43029                                 University of Bern  GCA_021136835.1
# 43030                                 University of Bern  GCA_021136845.1
# 43031                                 University of Bern  GCA_021136875.1
# 43032                                 University of Bern  GCA_021136895.1
# 43035                                 University of Bern  GCA_021136945.1
# 43036                                 University of Bern  GCA_021136955.1
# 43039                                 University of Bern  GCA_021137035.1
# 43044                                 University of Bern  GCA_021137135.1
# 43046                                 University of Bern  GCA_021137155.1
# 43047                                 University of Bern  GCA_021137165.1
# 43048                                 University of Bern  GCA_021137215.1
# 43049                                 University of Bern  GCA_021137235.1
# 43050                                 University of Bern  GCA_021137255.1
# 43051                                 University of Bern  GCA_021137275.1
# 43052                                 University of Bern  GCA_021137295.1
# 43053                                 University of Bern  GCA_021137315.1
#
#       paired_asm_comp                                           ftp_path  \
# 121         identical  https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/0...
# 2156        identical  https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/0...
# 3989        identical  https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/0...
# 6651        identical  https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/0...
# 6744        identical  https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/0...
# 9738        identical  https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/0...
# 9739        identical  https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/0...
# 9748        identical  https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/0...
# 10949       identical  https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/0...
# 19094       identical  https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/0...
# 23555       identical  https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/0...
# 36722       identical  https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/0...
# 36723       identical  https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/0...
# 36724       identical  https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/0...
# 36725       identical  https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/0...
# 36727       identical  https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/0...
# 36731       identical  https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/0...
# 36736       identical  https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/0...
# 36737       identical  https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/0...
# 36739       identical  https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/0...
# 36740       identical  https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/0...
# 36741       identical  https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/0...
# 36742       identical  https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/0...
# 36743       identical  https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/0...
# 36752       identical  https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/0...
# 36763       identical  https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/0...
# 43012       identical  https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/0...
# 43021       identical  https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/0...
# 43022       identical  https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/0...
# 43024       identical  https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/0...
# 43026       identical  https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/0...
# 43028       identical  https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/0...
# 43029       identical  https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/0...
# 43030       identical  https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/0...
# 43031       identical  https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/0...
# 43032       identical  https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/0...
# 43035       identical  https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/0...
# 43036       identical  https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/0...
# 43039       identical  https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/0...
# 43044       identical  https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/0...
# 43046       identical  https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/0...
# 43047       identical  https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/0...
# 43048       identical  https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/0...
# 43049       identical  https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/0...
# 43050       identical  https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/0...
# 43051       identical  https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/0...
# 43052       identical  https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/0...
# 43053       identical  https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/0...
#
#       excluded_from_refseq relation_to_type_material asm_not_live_date  \
# 121                    NaN                       NaN                na
# 2156                   NaN                       NaN                na
# 3989                   NaN                       NaN                na
# 6651                   NaN                       NaN                na
# 6744                   NaN                       NaN                na
# 9738                   NaN                       NaN                na
# 9739                   NaN                       NaN                na
# 9748                   NaN                       NaN                na
# 10949                  NaN                       NaN                na
# 19094                  NaN                       NaN                na
# 23555                  NaN                       NaN                na
# 36722                  NaN                       NaN                na
# 36723                  NaN                       NaN                na
# 36724                  NaN                       NaN                na
# 36725                  NaN                       NaN                na
# 36727                  NaN                       NaN                na
# 36731                  NaN                       NaN                na
# 36736                  NaN                       NaN                na
# 36737                  NaN                       NaN                na
# 36739                  NaN                       NaN                na
# 36740                  NaN                       NaN                na
# 36741                  NaN                       NaN                na
# 36742                  NaN                       NaN                na
# 36743                  NaN                       NaN                na
# 36752                  NaN                       NaN                na
# 36763                  NaN                       NaN                na
# 43012                  NaN                       NaN                na
# 43021                  NaN                       NaN                na
# 43022                  NaN                       NaN                na
# 43024                  NaN                       NaN                na
# 43026                  NaN                       NaN                na
# 43028                  NaN                       NaN                na
# 43029                  NaN                       NaN                na
# 43030                  NaN                       NaN                na
# 43031                  NaN                       NaN                na
# 43032                  NaN                       NaN                na
# 43035                  NaN                       NaN                na
# 43036                  NaN                       NaN                na
# 43039                  NaN                       NaN                na
# 43044                  NaN                       NaN                na
# 43046                  NaN                       NaN                na
# 43047                  NaN                       NaN                na
# 43048                  NaN                       NaN                na
# 43049                  NaN                       NaN                na
# 43050                  NaN                       NaN                na
# 43051                  NaN                       NaN                na
# 43052                  NaN                       NaN                na
# 43053                  NaN                       NaN                na
#
#                 species_name   genus_name domain_name
# 121         Escherichia coli  Escherichia    Bacteria
# 2156        Escherichia coli  Escherichia    Bacteria
# 3989   Klebsiella pneumoniae   Klebsiella    Bacteria
# 6651   Klebsiella pneumoniae   Klebsiella    Bacteria
# 6744        Escherichia coli  Escherichia    Bacteria
# 9738        Escherichia coli  Escherichia    Bacteria
# 9739   Klebsiella pneumoniae   Klebsiella    Bacteria
# 9748        Escherichia coli  Escherichia    Bacteria
# 10949       Escherichia coli  Escherichia    Bacteria
# 19094       Escherichia coli  Escherichia    Bacteria
# 23555       Escherichia coli  Escherichia    Bacteria
# 36722       Escherichia coli  Escherichia    Bacteria
# 36723       Escherichia coli  Escherichia    Bacteria
# 36724       Escherichia coli  Escherichia    Bacteria
# 36725       Escherichia coli  Escherichia    Bacteria
# 36727       Escherichia coli  Escherichia    Bacteria
# 36731       Escherichia coli  Escherichia    Bacteria
# 36736       Escherichia coli  Escherichia    Bacteria
# 36737       Escherichia coli  Escherichia    Bacteria
# 36739       Escherichia coli  Escherichia    Bacteria
# 36740       Escherichia coli  Escherichia    Bacteria
# 36741       Escherichia coli  Escherichia    Bacteria
# 36742       Escherichia coli  Escherichia    Bacteria
# 36743       Escherichia coli  Escherichia    Bacteria
# 36752       Escherichia coli  Escherichia    Bacteria
# 36763       Escherichia coli  Escherichia    Bacteria
# 43012  Klebsiella pneumoniae   Klebsiella    Bacteria
# 43021  Klebsiella pneumoniae   Klebsiella    Bacteria
# 43022  Klebsiella pneumoniae   Klebsiella    Bacteria
# 43024  Klebsiella pneumoniae   Klebsiella    Bacteria
# 43026  Klebsiella pneumoniae   Klebsiella    Bacteria
# 43028  Klebsiella pneumoniae   Klebsiella    Bacteria
# 43029  Klebsiella pneumoniae   Klebsiella    Bacteria
# 43030  Klebsiella pneumoniae   Klebsiella    Bacteria
# 43031  Klebsiella pneumoniae   Klebsiella    Bacteria
# 43032  Klebsiella pneumoniae   Klebsiella    Bacteria
# 43035  Klebsiella pneumoniae   Klebsiella    Bacteria
# 43036  Klebsiella pneumoniae   Klebsiella    Bacteria
# 43039  Klebsiella pneumoniae   Klebsiella    Bacteria
# 43044  Klebsiella pneumoniae   Klebsiella    Bacteria
# 43046  Klebsiella pneumoniae   Klebsiella    Bacteria
# 43047  Klebsiella pneumoniae   Klebsiella    Bacteria
# 43048  Klebsiella pneumoniae   Klebsiella    Bacteria
# 43049  Klebsiella pneumoniae   Klebsiella    Bacteria
# 43050  Klebsiella pneumoniae   Klebsiella    Bacteria
# 43051  Klebsiella pneumoniae   Klebsiella    Bacteria
# 43052  Klebsiella pneumoniae   Klebsiella    Bacteria
# 43053  Klebsiella pneumoniae   Klebsiella    Bacteria
#
# [48 rows x 27 columns]

# %%
# for i in range(1):
#     count = 0
#     for ii,row in complete_df.iterrows():    
#         genome_id = row['assembly_accession'] + '_' + row['asm_name']
#         genome_id = genome_id.replace(':','_')
#         genome_id = genome_id.replace(' ','_')
#         genome_id = genome_id.replace('/','_')
#         genome_id = genome_id.replace('#','_')

#         genome_file, annotation_file = download_refseq_assembly_curl(row['ftp_path'])
#         if (genome_file is None) or (annotation_file is None):        
#             break
#         # print(genome_id, row['species_name'])
#         count += 1
#     print(count)
#     #time.sleep(120)
# Out:
# 470

# %%
#look at pyspoa notebook to see how to align a test sequence into the msa
